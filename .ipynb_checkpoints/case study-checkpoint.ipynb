# %%
from tkinter import *
from tkinter import messagebox

windows = Tk()
windows.geometry("1350x750")
windows.title("Cafe manager")
windows.configure(background="blue")
#===========================================Function==========================================
def exit():
    exit = messagebox.askyesno("Thoát hệ thống", "Bạn có muốn thoát không?")
    if exit > 0:
        windows.destroy()
        return

def reset():
    tong_ety.set("")
    tien1_ety.set("")
    tien2_ety.set("")
    tien3_ety.set("") 
    khuyenmai_ety.set("") 
    vat_ety.set("") 
    info_text.delete("1.0", END)
    
    var1.set("0")
    var2.set("0")
    var3.set("0")
    var4.set("0")
    var5.set("0")
    var6.set("0")
    var7.set("0")
    var8.set("0")
    var9.set("0")
    var11.set("0")
    var12.set("0")
    var13.set("0")
    var14.set("0")
    var15.set("0")
    var10.set("0")
    var16.set("0")
    var17.set("0")
    var18.set("0")
    var19.set("0")
    var20.set("0")
    var21.set("0")
    var22.set("0")
    var23.set("0")
    var24.set("0")
    
    e_cafe.set("0")
    e_cafeS.set("0")
    e_cafeK.set("0")
    e_cafeD.set("0")
    e_bacSuu.set("0")
    e_cacao.set("0")
    e_miloRamTc.set("0")
    e_miloRamDb.set("0")
    e_traOlong.set("0")
    e_traDao.set("0")
    e_traTac.set("0")
    e_traChanh.set("0")
    e_traXoai.set("0")
    e_traNhadam.set("0")
    e_traKiwi.set("0")
    e_traVai.set("0") 
    e_banhFlan.set("0")
    e_banhSua.set("0")
    e_ram.set("0")
    e_phoMai.set("0")
    e_cavien.set("0")
    e_xucxich.set("0")
    e_khoaiTay.set("0")
    e_kho.set("0")
    
    cafe_e.configure(state=DISABLED)
    cafeSua_e.configure(state=DISABLED)
    cafeKem_e.configure(state=DISABLED)
    cafeDua_e.configure(state=DISABLED)
    bacSuu_e.configure(state=DISABLED)
    cacao_e.configure(state=DISABLED)
    miloRamTc_e.configure(state=DISABLED)
    miloRamDb_e.configure(state=DISABLED)
    traOlong_e.configure(state=DISABLED)
    traDao_e.configure(state=DISABLED)
    traTac_e.configure(state=DISABLED)
    traChanh_e.configure(state=DISABLED)
    traXoai_e.configure(state=DISABLED)
    traNhadam_e.configure(state=DISABLED)
    traKiwi_e.configure(state=DISABLED)
    traVai_e.configure(state=DISABLED)
    banhFlan_e.configure(state=DISABLED)
    banhSua_e.configure(state=DISABLED)
    ram_e.configure(state=DISABLED)
    phoMai_e.configure(state=DISABLED)
    cavien_e.configure(state=DISABLED)
    xucxich_e.configure(state=DISABLED)
    khoaiTay_e.configure(state=DISABLED)
    kho_e.configure(state=DISABLED)

def check_but():
    if (var1.get()) == 1:
        cafe_e.configure(state=NORMAL)
    elif (var1.get()) == 1:
        cafe_e.configure(state=DISABLED)
        e_cafe.set("0")
    if (var2.get()) == 1:
        cafeSua_e.configure(state=NORMAL)
    elif (var2.get()) == 0:
        cafeSua_e.configure(state=DISABLED)
        e_cafeS.set("0")
    if (var3.get()) == 1:
        cafeKem_e.configure(state=NORMAL)
    elif (var3.get()) == 0:
        cafeKem_e.configure(state=DISABLED)
        e_cafeK.set("0")
    if (var4.get()) == 1:
        cafeDua_e.configure(state=NORMAL)
    elif (var4.get()) == 0:
        cafeDua_e.configure(state=DISABLED)
        e_cafeD.set("0")
    if (var5.get()) == 1:
        bacSuu_e.configure(state=NORMAL)
    elif (var5.get()) == 0:
        bacSuu_e.configure(state=DISABLED)
        e_bacSuu.set("0")
    if (var6.get()) == 1:
        cacao_e.configure(state=NORMAL)
    elif (var6.get()) == 0:
        cacao_e.configure(state=DISABLED)
        e_cacao.set("0")
    if (var7.get()) == 1:
        miloRamTc_e.configure(state=NORMAL)
    elif (var7.get()) == 0:
        miloRamTc_e.configure(state=DISABLED)
        e_miloRamTc.set("0")
    if (var8.get()) == 1:
        miloRamDb_e.configure(state=NORMAL)
    elif (var8.get()) == 0:
        miloRamDb_e.configure(state=DISABLED)
        e_miloRamDb.set("0")
    if (var9.get()) == 1:
        traOlong_e.configure(state=NORMAL)
    elif (var9.get()) == 0:
        traOlong_e.configure(state=DISABLED)
        e_traOlong.set("0")
    if (var10.get()) == 1:
        traDao_e.configure(state=NORMAL)
    elif (var10.get()) == 0:
        traDao_e.configure(state=DISABLED)
        e_traDao.set("0")
    if (var11.get()) == 1:
        traTac_e.configure(state=NORMAL)
    elif (var11.get()) == 0:
        traTac_e.configure(state=DISABLED)
        e_traTac.set("0")
    if (var12.get()) == 1:
        traChanh_e.configure(state=NORMAL)
    elif (var12.get()) == 0:
        traChanh_e.configure(state=DISABLED)
        e_traChanh.set("0")
    if (var13.get()) == 1:
        traXoai_e.configure(state=NORMAL)
    elif (var13.get()) == 0:
        traXoai_e.configure(state=DISABLED)
        e_traXoai.set("0")
    if (var14.get()) == 1:
        traNhadam_e.configure(state=NORMAL)
    elif (var14.get()) == 0:
        traNhadam_e.configure(state=DISABLED)
        e_traNhadam.set("0")
    if (var15.get()) == 1:
        traKiwi_e.configure(state=NORMAL)
    elif (var15.get()) == 0:
        traKiwi_e.configure(state=DISABLED)
        e_traKiwi.set("0")
    if (var16.get()) == 1:
        traVai_e.configure(state=NORMAL)
    elif (var16.get()) == 0:
        traVai_e.configure(state=DISABLED)
        e_traVai.set("0") 
    if (var17.get()) == 1:
        banhFlan_e.configure(state=NORMAL)
    elif (var17.get()) == 0:
        banhFlan_e.configure(state=DISABLED)
        e_banhFlan.set("0")
    if (var18.get()) == 1:
        banhSua_e.configure(state=NORMAL)
    elif (var18.get()) == 0:
        banhSua_e.configure(state=DISABLED)
        e_banhSua.set("0")
    if (var19.get()) == 1:
        ram_e.configure(state=NORMAL)
    elif (var19.get()) == 0:
        ram_e.configure(state=DISABLED)
        e_ram.set("0")
    if (var20.get()) == 1:
        phoMai_e.configure(state=NORMAL)
    elif (var20.get()) == 0:
        phoMai_e.configure(state=DISABLED)
        e_phoMai.set("0")
    if (var21.get()) == 1:
        cavien_e.configure(state=NORMAL)
    elif (var21.get()) == 0:
        cavien_e.configure(state=DISABLED)
        e_cavien.set("0")
    if (var22.get()) == 1:
        xucxich_e.configure(state=NORMAL)
    elif (var22.get()) == 0:
        xucxich_e.configure(state=DISABLED)
        e_xucxich.set("0")
    if (var23.get()) == 1:
        khoaiTay_e.configure(state=NORMAL)
    elif (var23.get()) == 0:
        khoaiTay_e.configure(state=DISABLED)
        e_khoaiTay.set("0")
    if (var24.get()) == 1:
        kho_e.configure(state=NORMAL)
    elif (var24.get()) == 0:
        kho_e.configure(state=DISABLED)
        e_kho.set("0") 

def tong_tien():
    item1 = float(e_cafe.get())
    item2 = float(e_cafeS.get())
    item3 = float(e_cafeK.get())
    item4 = float(e_cafeD.get())
    item5 = float(e_bacSuu.get())
    item6 = float(e_cacao.get())
    item7 = float(e_miloRamTc.get())
    item8 = float(e_miloRamDb.get())
    item9 = float(e_traOlong.get())
    item10 = float(e_traDao.get())
    item11 = float(e_traTac.get())
    item12 = float(e_traChanh.get())
    item13 = float(e_traXoai.get())
    item14 = float(e_traNhadam.get())
    item15 = float(e_traKiwi.get())
    item16 = float(e_traVai.get())
    item17 = float(e_banhFlan.get())
    item18 = float(e_banhSua.get())
    item19 = float(e_ram.get())
    item20 = float(e_phoMai.get())
    item21 = float(e_cavien.get())
    item22 = float(e_xucxich.get())
    item23 = float(e_khoaiTay.get())
    item24 = float(e_kho.get())
    
    tong1 = (item1*15.000) + (item2*18.000) + (item3*25.000) + (item4*29.000) + (item5*20.000) + (item6*22.000)\
            + (item7*29.000) + (item8*34.000)
    tong2 = (item9*23.000) + (item10*19.000) + (item11*19.000) + (item12*19.000) + (item13*22.000) + (item14*22.000)\
            + (item15*22.000) + (item16*25.000)
    tong3 = (item17*15.000) + (item18*5.000) + (item19*10.000) + (item20*8.000) + (item21*12.000) + (item22*10.000)\
            + (item23*25.000) + (item24*35.000)
    
    km_e = (int(khuyenmai_e.get())*(tong1 + tong2 + tong3))/100
    
    tong_tien1 = str("%.3f"%(tong1)), "₫"
    tong_tien2 = str("%.3f"%(tong2)), "₫"
    tong_tien3 = str("%.3f"%(tong3)), "₫"
    km = str("%.3f"%km_e), "₫"
    vat = str("%.3f"%((tong1 + tong2 + tong3)/10)), "₫"
    tt = str("%.3f"%(tong1 + tong2 + tong3), "₫"
    
    tien1_ety.set(tong_tien1)
    tien2_ety.set(tong_tien2)
    tien3_ety.set(tong_tien3)
    khuyenmai_ety.set(km)
    vat_ety.set(vat)
    tong_ety.set(tt)
    
#===========================================FRAME=============================================
khung1 = Frame(windows, height=100, width=1350, relief="raise",bd=14)
khung1.pack(side = TOP)

khung2 = Frame(windows, height=650, width=900, relief="raise",bd=14)
khung2.pack(side = LEFT)
khung2.configure(background="blue")

khung21 = Frame(khung2, height=400, width=900, relief="raise",bd=8)
khung21.pack(side = TOP)

khung211 = Frame(khung21, height=400, width=300, relief="raise",bd=6)
khung211.pack(side = LEFT)

khung213 = Frame(khung21, height=400, width=300, relief="raise",bd=6)
khung213.pack(side = RIGHT)

khung212 = Frame(khung21, height=400, width=300, relief="raise",bd=6)
khung212.pack(side = RIGHT)

khung22 = Frame(khung2, height=250, width=900, relief="raise",bd=8)
khung22.pack(side = BOTTOM)

khung3 = Frame(windows, height=650, width=450, relief="raise",bd=14)
khung3.pack(side = RIGHT)
khung3.configure(background="blue")

khung31 = Frame(khung3, height=450, width=450, relief="raise", bd=8)
khung31.pack(side=TOP)

khung32 = Frame(khung3, height=200, width=450, relief="raise", bd=8)
khung32.pack(side=BOTTOM)

#===========================================label=============================================
khung1_lbl = Label(khung1, text="CAFÉ MANAGER SYSTEMS", font=("arial", 75, "bold"))
khung1_lbl.grid(column=0, row=0)

cafe_lbl = Label(khung211, text="CAFÉ", font=("arial", 20, "bold"))
cafe_lbl.grid(column=0, row=0, columnspan=2)

tra_lbl = Label(khung212, text="TRÀ", font=("arial", 20, "bold"))
tra_lbl.grid(column=0, row=0, columnspan=2)

an_lbl = Label(khung213, text="CÁC MÓN ĂN", font=("arial", 20, "bold"))
an_lbl.grid(column=0, row=0, columnspan=2)

tien1 = Label(khung22, text="Tiền cafe", font=("arial", 14, "bold"))
tien1.grid(column=0, row=0, sticky=W)

tien2 = Label(khung22, text="Tiền trà", font=("arial", 14, "bold"))
tien2.grid(column=2, row=0, sticky=W)

tien3 = Label(khung22, text="Tiền đồ ăn", font=("arial", 14, "bold"))
tien3.grid(column=4, row=0, sticky=W)

khuyenmai = Label(khung22, text="Khuyến mãi", font=("arial", 14, "bold"))
khuyenmai.grid(column=0, row=1, sticky=W)

vat = Label(khung22, text="Thuế VAT", font=("arial", 14, "bold"))
vat.grid(column=2, row=1, sticky=W)

tong = Label(khung22, text="TỔNG TIỀN", font=("arial", 14, "bold"), fg="red")
tong.grid(column=4, row=1, sticky=W)

info_lbl = Label(khung31, text="Thông tin hóa đơn:", font=("arial", 12, "bold"), bd=2)
info_lbl.grid(column=0, row=0, sticky=W)

#===========================================text=============================================
info_text = Text(khung31, font=("arial", 11, "bold"), bd=8, width=59)
info_text.grid(column=0, row=1)
#===========================================button=============================================
tong_but = Button(khung32, text="TỔNG", bd=4, padx=16, pady=1, fg="black", font=("arial", 12, "bold"), 
                  width=5, command=tong_tien)
tong_but.grid(column=0, row=0)

hoaDon_but = Button(khung32, text="HÓA ĐƠN", bd=4, padx=16, pady=1, fg="black", font=("arial", 12, "bold"), width=5)
hoaDon_but.grid(column=1, row=0)

reset_but = Button(khung32, text="RESET", bd=4, padx=16, pady=1, fg="black",command=reset, font=("arial", 12, "bold"), width=5)
reset_but.grid(column=2, row=0)

exit_but = Button(khung32, text="THOÁT", bd=4, padx=16, pady=1, fg="black",command=exit, font=("arial", 12, "bold"), width=5)
exit_but.grid(column=3, row=0)
#===========================================checkbutton=============================================
#khung211
var1 = IntVar()
var2 = IntVar()
var3 = IntVar()
var4 = IntVar()
var5 = IntVar()
var6 = IntVar()
var7 = IntVar()
var8 = IntVar()

var1.set("0")
var2.set("0")
var3.set("0")
var4.set("0")
var5.set("0")
var6.set("0")
var7.set("0")
var8.set("0")

cafe_cbt = Checkbutton(khung211, text="Cafe đen", fg="teal", font=("arial", 18, "bold"), 
                       variable = var1, onvalue=1, offvalue=0, command=check_but)
cafe_cbt.grid(column=0, row=1, sticky=W)

cafeSua_cbt = Checkbutton(khung211, text="Cafe Sữa", fg="teal", font=("arial", 18, "bold"), 
                          variable = var2, onvalue=1, offvalue=0, command=check_but)
cafeSua_cbt.grid(column=0, row=2, sticky=W)

cafeKem_cbt = Checkbutton(khung211, text="Cafe Kem", fg="teal", font=("arial", 18, "bold"), 
                          variable = var3, onvalue=1, offvalue=0, command=check_but)
cafeKem_cbt.grid(column=0, row=3, sticky=W)

cafeDua_cbt = Checkbutton(khung211, text="Cafe Cốt Dừa", fg="teal", font=("arial", 18, "bold"), 
                          variable = var4, onvalue=1, offvalue=0, command=check_but)
cafeDua_cbt.grid(column=0, row=4, sticky=W)

bacSuu_cbt = Checkbutton(khung211, text="Bạc Sửu", fg="teal", font=("arial", 18, "bold"), 
                         variable = var5, onvalue=1, offvalue=0, command=check_but)
bacSuu_cbt.grid(column=0, row=5, sticky=W)

cacao_cbt = Checkbutton(khung211, text="Cacao Bánh", fg="teal", font=("arial", 18, "bold"), 
                        variable = var6, onvalue=1, offvalue=0, command=check_but)
cacao_cbt.grid(column=0, row=6, sticky=W)

miloRamTC_cbt = Checkbutton(khung211, text="Milo TC", fg="teal", font=("arial", 18, "bold"), 
                            variable = var7, onvalue=1, offvalue=0, command=check_but)
miloRamTC_cbt.grid(column=0, row=7, sticky=W)

miloRamDb_cbt = Checkbutton(khung211, text="Milo Đặc Biệt", fg="teal", font=("arial", 18, "bold"), 
                         variable = var8, onvalue=1, offvalue=0, command=check_but)
miloRamDb_cbt.grid(column=0, row=8, sticky=W)

#khung212
var9 = IntVar()
var10 = IntVar()
var11 = IntVar()
var12 = IntVar()
var13 = IntVar()
var14 = IntVar()
var15 = IntVar()
var16 = IntVar()

var9.set("0")
var11.set("0")
var12.set("0")
var13.set("0")
var14.set("0")
var15.set("0")
var10.set("0")
var16.set("0")

traOlong_cbt = Checkbutton(khung212, text="Trà Ô Long", fg="teal", font=("arial", 18, "bold"), 
                       variable = var9, onvalue=1, offvalue=0, command=check_but)
traOlong_cbt.grid(column=0, row=1, sticky=W)

traDao_cbt = Checkbutton(khung212, text="Trà Đào", fg="teal", font=("arial", 18, "bold"), 
                       variable = var10, onvalue=1, offvalue=0, command=check_but)
traDao_cbt.grid(column=0, row=2, sticky=W)

traTac_cbt = Checkbutton(khung212, text="Trà Tắc Xí Muội", fg="teal", font=("arial", 18, "bold"), 
                       variable = var11, onvalue=1, offvalue=0, command=check_but)
traTac_cbt.grid(column=0, row=3, sticky=W)

traChanh_cbt = Checkbutton(khung212, text="Trà Chanh Xí Muội", fg="teal", font=("arial", 18, "bold"), 
                       variable = var12, onvalue=1, offvalue=0, command=check_but)
traChanh_cbt.grid(column=0, row=4, sticky=W)

traXoai_cbt = Checkbutton(khung212, text="Trà Xoài Nha Dam", fg="teal", font=("arial", 18, "bold"), 
                       variable = var13, onvalue=1, offvalue=0, command=check_but)
traXoai_cbt.grid(column=0, row=5, sticky=W)

traNhadam_cbt = Checkbutton(khung212, text="Trà Nha Dam", fg="teal", font=("arial", 18, "bold"), 
                       variable = var14, onvalue=1, offvalue=0, command=check_but)
traNhadam_cbt.grid(column=0, row=6, sticky=W)

traKiwi_cbt = Checkbutton(khung212, text="Trà Kiwi Nha Đam", fg="teal", font=("arial", 18, "bold"), 
                       variable = var15, onvalue=1, offvalue=0, command=check_but)
traKiwi_cbt.grid(column=0, row=7, sticky=W)

traVai_cbt = Checkbutton(khung212, text="Trà Trái Vải", fg="teal", font=("arial", 18, "bold"), 
                       variable = var16, onvalue=1, offvalue=0, command=check_but)
traVai_cbt.grid(column=0, row=8, sticky=W)

#khung213
var17 = IntVar()
var18 = IntVar()
var19 = IntVar()
var20 = IntVar()
var21 = IntVar()
var22 = IntVar()
var23 = IntVar()
var24 = IntVar()

var17.set("0")
var18.set("0")
var19.set("0")
var20.set("0")
var21.set("0")
var22.set("0")
var23.set("0")
var24.set("0")

banhFlan_cbt = Checkbutton(khung213, text="Bánh Flan", fg="teal", font=("arial", 18, "bold"), 
                       variable = var17, onvalue=1, offvalue=0, command=check_but)
banhFlan_cbt.grid(column=0, row=1, sticky=W)

banhSua_cbt = Checkbutton(khung213, text="Bánh Sữa Tươi", fg="teal", font=("arial", 18, "bold"), 
                       variable = var18, onvalue=1, offvalue=0, command=check_but)
banhSua_cbt.grid(column=0, row=2, sticky=W)

ram_cbt = Checkbutton(khung213, text="Ram Hải Sản", fg="teal", font=("arial", 18, "bold"), 
                       variable = var19, onvalue=1, offvalue=0, command=check_but)
ram_cbt.grid(column=0, row=3, sticky=W)

phoMai_cbt = Checkbutton(khung213, text="Phomai Que", fg="teal", font=("arial", 18, "bold"), 
                       variable = var20, onvalue=1, offvalue=0, command=check_but)
phoMai_cbt.grid(column=0, row=4, sticky=W)

cavien_cbt = Checkbutton(khung213, text="Cá viên", fg="teal", font=("arial", 18, "bold"), 
                       variable = var21, onvalue=1, offvalue=0, command=check_but)
cavien_cbt.grid(column=0, row=5, sticky=W)

xucxich_cbt = Checkbutton(khung213, text="Xúc Xích Đức", fg="teal", font=("arial", 18, "bold"), 
                       variable = var22, onvalue=1, offvalue=0, command=check_but)
xucxich_cbt.grid(column=0, row=6, sticky=W)

khoaiTay_cbt = Checkbutton(khung213, text="Khoai Tay Lắc", fg="teal", font=("arial", 18, "bold"), 
                       variable = var23, onvalue=1, offvalue=0, command=check_but)
khoaiTay_cbt.grid(column=0, row=7, sticky=W)

kho_cbt = Checkbutton(khung213, text="Khô Gà Lá Chanh", fg="teal", font=("arial", 18, "bold"), 
                       variable = var24, onvalue=1, offvalue=0, command=check_but)
kho_cbt.grid(column=0, row=8, sticky=W)

#===========================================Entry=============================================
#khung211
e_cafe=StringVar()
e_cafeS=StringVar()
e_cafeK=StringVar()
e_cafeD=StringVar()
e_bacSuu=StringVar()
e_cacao=StringVar()
e_miloRamTc=StringVar()
e_miloRamDb=StringVar()

e_cafe.set("0")
e_cafeS.set("0")
e_cafeK.set("0")
e_cafeD.set("0")
e_bacSuu.set("0")
e_cacao.set("0")
e_miloRamTc.set("0")
e_miloRamDb.set("0")

cafe_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4",textvariable=e_cafe, justify="right", state=DISABLED)
cafe_e.grid(column=1, row=1)

cafeSua_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4",textvariable=e_cafeS, justify="right", state=DISABLED)
cafeSua_e.grid(column=1, row=2)

cafeKem_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_cafeK,justify="right", state=DISABLED)
cafeKem_e.grid(column=1, row=3)

cafeDua_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_cafeD,justify="right", state=DISABLED)
cafeDua_e.grid(column=1, row=4)

bacSuu_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_bacSuu,justify="right", state=DISABLED)
bacSuu_e.grid(column=1, row=5)

cacao_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_cacao,justify="right", state=DISABLED)
cacao_e.grid(column=1, row=6)

miloRamTc_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_miloRamTc,justify="right", state=DISABLED)
miloRamTc_e.grid(column=1, row=7)

miloRamDb_e = Entry(khung211, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_miloRamDb,justify="right", state=DISABLED)
miloRamDb_e.grid(column=1, row=8)

#khung212
e_traOlong=StringVar()
e_traDao=StringVar()
e_traTac=StringVar()
e_traChanh=StringVar()
e_traXoai=StringVar()
e_traNhadam=StringVar()
e_traKiwi=StringVar()
e_traVai=StringVar()

e_traOlong.set("0")
e_traDao.set("0")
e_traTac.set("0")
e_traChanh.set("0")
e_traXoai.set("0")
e_traNhadam.set("0")
e_traKiwi.set("0")
e_traVai.set("0")

traOlong_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traOlong, justify="right", state=DISABLED)
traOlong_e.grid(column=1, row=1)

traDao_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traDao, justify="right", state=DISABLED)
traDao_e.grid(column=1, row=2)

traTac_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traTac,justify="right", state=DISABLED)
traTac_e.grid(column=1, row=3)

traChanh_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traChanh,justify="right", state=DISABLED)
traChanh_e.grid(column=1, row=4)

traXoai_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traXoai,justify="right", state=DISABLED)
traXoai_e.grid(column=1, row=5)

traNhadam_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traNhadam,justify="right", state=DISABLED)
traNhadam_e.grid(column=1, row=6)

traKiwi_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traKiwi,justify="right", state=DISABLED)
traKiwi_e.grid(column=1, row=7)

traVai_e = Entry(khung212, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_traVai,justify="right", state=DISABLED)
traVai_e.grid(column=1, row=8)

#khung213
e_banhFlan=StringVar()
e_banhSua=StringVar()
e_ram=StringVar()
e_phoMai=StringVar()
e_cavien=StringVar()
e_xucxich=StringVar()
e_khoaiTay=StringVar()
e_kho=StringVar()

e_banhFlan.set("0")
e_banhSua.set("0")
e_ram.set("0")
e_phoMai.set("0")
e_cavien.set("0")
e_xucxich.set("0")
e_khoaiTay.set("0")
e_kho.set("0")

banhFlan_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_banhFlan,justify="right", state=DISABLED)
banhFlan_e.grid(column=1, row=1)

banhSua_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_banhSua,justify="right", state=DISABLED)
banhSua_e.grid(column=1, row=2)

ram_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_ram,justify="right", state=DISABLED)
ram_e.grid(column=1, row=3)

phoMai_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_phoMai,justify="right", state=DISABLED)
phoMai_e.grid(column=1, row=4)

cavien_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_cavien,justify="right", state=DISABLED)
cavien_e.grid(column=1, row=5)

xucxich_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_xucxich,justify="right", state=DISABLED)
xucxich_e.grid(column=1, row=6)

khoaiTay_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_khoaiTay,justify="right", state=DISABLED)
khoaiTay_e.grid(column=1, row=7)

kho_e = Entry(khung213, font=("arial", 16, "bold"), bd="8", width="4", textvariable=e_kho,justify="right", state=DISABLED)
kho_e.grid(column=1, row=8)

#khung22
tong_ety=StringVar()
tien1_ety=StringVar()
tien2_ety=StringVar()
tien3_ety=StringVar()
khuyenmai_ety=StringVar()
vat_ety=StringVar()

tong_ety.set("")
tien1_ety.set("")
tien2_ety.set("")
tien3_ety.set("") 
khuyenmai_ety.set("") 
vat_ety.set("") 

tien1_e = Entry(khung22, font=("arial", 18, "bold"), bd="8", width="13",textvariable=tien1_ety, justify="right")
tien1_e.grid(column=1, row=0)

tien2_e = Entry(khung22, font=("arial", 18, "bold"), bd="8", width="13",textvariable=tien2_ety, justify="right")
tien2_e.grid(column=3, row=0)

tien3_e = Entry(khung22, font=("arial", 18, "bold"), bd="8", width="13",textvariable= tien3_ety, justify="right")
tien3_e.grid(column=5, row=0)

khuyenmai_e = Entry(khung22, font=("arial", 18, "bold"), bd="8", width="13",textvariable=khuyenmai_ety, justify="right")
khuyenmai_e.grid(column=1, row=1)

vat_e = Entry(khung22, font=("arial", 18, "bold"), bd="8", width="13",textvariable=vat_ety, justify="right")
vat_e.grid(column=3, row=1)

tong_e = Entry(khung22, font=("arial", 18, "bold"), bd="8", width="13", justify="right",textvariable=tong_ety, 
               bg="#FFFFCC", fg="red")
tong_e.grid(column=5, row=1)

#===========================================Entry=============================================


windows.mainloop()
# Out:
#   Input In [3]
#     tt = str("%.3f"%(tong1 + tong2 + tong3), "₫"
#                                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
